# %%
pip install -U googlemaps

# %%
import csv
import pandas as pd
import googlemaps

# %%
data = pd.read_csv('Station_List.csv',encoding="ISO-8859-1")
df = data.copy()
df.head()
# Out:
#    ï»¿Sequence           State               City  \
# 0            1  Andhra_Pradesh          Amaravati
# 1            2  Andhra_Pradesh  Rajamahendravaram
# 2            3  Andhra_Pradesh           Tirupati
# 3            4  Andhra_Pradesh         Vijayawada
# 4            5  Andhra_Pradesh      Visakhapatnam
#
#                                    Address
# 0                   Secretariat, Amaravati
# 1  Anand Kala Kshetram, Rajamahendravaram
# 2                      Tirumala, Tirupati
# 3                 PWD Grounds, Vijayawada
# 4           GVM Corporation, Visakhapatnam

# %%
df = df[['Address']]
df = df.drop_duplicates()

# %%
gmaps_key = googlemaps.Client(key="AIzaSyAQgM5sCL_8FG0r6au3c7LhS7dQzCEplYQ")

# %%
add_1 = df['Address'][190]
add_1
# g = gmaps_key.geocode(add_1)

# lat = g[0]["geometry"]["location"]["lat"]
# long = g[0]["geometry"]["location"]["lng"]
# print('Latitude: '+str(lat)+', Longitude: '+str(long))
# Out:
# 'Deen Dayal Nagar, Sagar '

# %%
addresses = df['Address'].tolist()

# %%
for address in addresses:
  add_1 = address
  g = gmaps_key.geocode(add_1)

  lat = g[0]["geometry"]["location"]["lat"]
  long = g[0]["geometry"]["location"]["lng"]
  print('Latitude: '+str(lat)+', Longitude: '+str(long))
# Out:
# Latitude: 16.5045615, Longitude: 80.5235168
# Latitude: 16.9955344, Longitude: 81.777335
# Latitude: 13.6807357, Longitude: 79.3508975
# Latitude: 16.5064045, Longitude: 80.6320387
# Latitude: 17.6868159, Longitude: 83.2184815
# Latitude: 27.1086309, Longitude: 93.69839789999999
# Latitude: 26.1795873, Longitude: 91.78431499999999
# Latitude: 26.1859679, Longitude: 91.7453642
# Latitude: 26.1475707, Longitude: 87.45668169999999
# Latitude: 25.5626095, Longitude: 84.663264
# Latitude: 24.7548649, Longitude: 84.3680054
# Latitude: 25.4445116, Longitude: 86.1399615
# Latitude: 26.8040197, Longitude: 84.5104212
# Latitude: 25.2610043, Longitude: 87.0086927
# Latitude: 25.2506776, Longitude: 86.9897915
# Latitude: 25.2033713, Longitude: 85.5142297
# Latitude: 25.5580341, Longitude: 83.9499487
# Latitude: 25.7827064, Longitude: 84.7459203
# Latitude: 26.1514392, Longitude: 85.8934836
# Latitude: 24.7910392, Longitude: 85.00636399999999
# Latitude: 24.7625227, Longitude: 84.9804538
# ...

# %%
# geocode the entire dataframe:

def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat, lng)

df['geocoded'] = df['Address'].apply(geocode)

# %%
df.head()
# Out:
#                                    Address                  geocoded
# 0                   Secretariat, Amaravati  (16.5045615, 80.5235168)
# 1  Anand Kala Kshetram, Rajamahendravaram    (16.9955344, 81.777335)
# 2                      Tirumala, Tirupati   (13.6807357, 79.3508975)
# 3                 PWD Grounds, Vijayawada   (16.5064045, 80.6320387)
# 4           GVM Corporation, Visakhapatnam  (17.6868159, 83.2184815)

# %%
# geocode the entire dataframe:

def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lat)

df['lattitude'] = df['Address'].apply(geocode)

# %%
df.head()
# Out:
#                                    Address                  geocoded  \
# 0                   Secretariat, Amaravati  (16.5045615, 80.5235168)
# 1  Anand Kala Kshetram, Rajamahendravaram    (16.9955344, 81.777335)
# 2                      Tirumala, Tirupati   (13.6807357, 79.3508975)
# 3                 PWD Grounds, Vijayawada   (16.5064045, 80.6320387)
# 4           GVM Corporation, Visakhapatnam  (17.6868159, 83.2184815)
#
#    lattitude
# 0  16.504562
# 1  16.995534
# 2  13.680736
# 3  16.506404
# 4  17.686816

# %%
# geocode the entire dataframe:

def geocode(add):
    g = gmaps_key.geocode(add)
    lat = g[0]["geometry"]["location"]["lat"]
    lng = g[0]["geometry"]["location"]["lng"]
    return (lng)

df['longitude'] = df['Address'].apply(geocode)

# %%
df.head()
# Out:
#                                    Address                  geocoded  \
# 0                   Secretariat, Amaravati  (16.5045615, 80.5235168)
# 1  Anand Kala Kshetram, Rajamahendravaram    (16.9955344, 81.777335)
# 2                      Tirumala, Tirupati   (13.6807357, 79.3508975)
# 3                 PWD Grounds, Vijayawada   (16.5064045, 80.6320387)
# 4           GVM Corporation, Visakhapatnam  (17.6868159, 83.2184815)
#
#    lattitude  longitude
# 0  16.504562  80.523517
# 1  16.995534  81.777335
# 2  13.680736  79.350898
# 3  16.506404  80.632039
# 4  17.686816  83.218481

# %%
df.to_csv("with_lat_long.csv")
